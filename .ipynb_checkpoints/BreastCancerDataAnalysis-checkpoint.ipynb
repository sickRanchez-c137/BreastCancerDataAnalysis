# %% [markdown]
# # Breast Cancer Data Analysis
# ## Submitted by Sick Ranchez C137
# The data set is obtaied from https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/data.

# %% [markdown]
# ### Following cell imports important libraries and packages required for succcessful operation
# These are just the basic ones. Other required packages will be added as needed. Please make sure following are installed in your machine for successful operation of this assignment:
# * numpy
# * pandas
# * matplotlib
# * sklearn
# * mplot3d-dragger
#
# We will use following classification techniques in this example.

# %% [markdown]
# | Classification Method |
# |------|
# | Random Forest (Gini) |
# | Random Forest (Entropy) |
# | Multi Layer Perception |
# | SVM NuSVC |
# | SVM LinearSVC |
# | SVM SVC Linear |
# | SVM SVC RBF |
# | Gaussian Naive Bayes |
# | Decision Tree (Gini) |
# | Decision Tree (Entropy) |
# | Logistic Regression |
# | KNN |

# %%
# this cell is for importing basic libraries that might be required
# .. also checks the version of python
import os
import sys
import os.path
import numpy as np
import pandas as pd
import numpy.linalg as la
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib.pylab import rcParams

# tools we need
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

# model we might use
from sklearn import tree
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

#analysis of models
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

# %matplotlib inline

print(sys.version)
# Out:
# 3.6.8 (v3.6.8:3c6b436a57, Dec 24 2018, 02:04:31)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %% [markdown]
# ### We will read the file as pandas dataframe
# Here we will check for the existance of file. If the file is not found, we exit, else we will read it as a pandas dataframe

# %%
# let us read the data from data.csv file as pandas dataframe

# name the file
data_file_name = 'data.csv'
# check the existance of file
# .. if the file is not found, exit
if not os.path.isfile(data_file_name):
    print(f'File {data_file_name} not found. Please make sure the file is locatable and change the name of file in variable above')
    sys.exit(-1)
    
# read the file as pandas dataframe
my_dataframe = pd.read_csv('data.csv')
# let us see the first 5 lines of the file
my_dataframe.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(my_dataframe['Unnamed: 32'])
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 564   NaN
# 565   NaN
# 566   NaN
# 567   NaN
# 568   NaN
# Name: Unnamed: 32, Length: 569, dtype: float64

# %% [markdown]
# ### From the above data, following observations can be made
# * 'id' is irrelevant, we can ge rid of that
# * 'diagnosis' is class label
# * 'Unnamed: 32' can essentially be removed since all the values are 'nan'
# ### Thus we can rearrange the data to
# * remove the 'id'
# * remove 'Unnamed: 32'
# * create X-matrix with all the observations X attributes
# * create Y-matrix with all the labels of data

# %%
# get the column names as a list
col_list = my_dataframe.columns.to_list()
# rearrange the column names such that the 'diagnosis' is the last column
my_dataFrameX = my_dataframe[col_list[2:-1]]
my_dataFrameY = my_dataframe[col_list[1]]
print(f'Peek into the X-values:\n {my_dataFrameX.head()}')
print(f'Peek into the Y-values:\n {my_dataFrameY.head()}')

my_dataX = my_dataFrameX.iloc[:].values
my_dataY = my_dataFrameY.iloc[:].values
# Out:
# Peek into the X-values:
#     radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
# ...

# %% [markdown]
# ## Analysis: Correlation Analysis

# %% [markdown]
# ### Numpy's corrcoef

# %%
# let us compute the correlation matrix of our dataset
# .. the result should be 30X30 symmetric matrix
correlation_matrix = np.corrcoef(my_dataX.T)
print(f'The correlation matrix computed as {correlation_matrix.shape} matrix')

## Let us print the correlation matrix using matplotlib
plt.matshow(correlation_matrix)
plt.colorbar()
# Out:
# The correlation matrix computed as (30, 30) matrix

# %% [markdown]
# ## Test Train Split
# Using SciKit Learn, we will split out data set into test and train sets. We will use 80/20 split, and we will only create test and train set split rather than train,test and validation set split. 3-way split as in train,test and validation is needed for Neural Networks and like. We will perform 3 way split as needed.

# %%
X_train,X_test,Y_train,Y_test = train_test_split(my_dataX,my_dataY,test_size=0.2, random_state=4)
print(f'Train-Test Data Size:\n-----------------\nX_train:{X_train.shape}, Y_train:{Y_train.shape}\nX_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Train-Test Data Size:
# -----------------
# X_train:(455, 30), Y_train:(455,)
# X_test:(114, 30), Y_test:(114,)

# %% [markdown]
# ## Analysis: Dimensionality Reduction (Probing)

# %% [markdown]
# ### Let us perform dimensionality reduction
# For dimensinality reduction, although there is a library available, we will use the technique taught to us, ie. using SVD technique.

# %%
X_train_mean = np.mean(X_train,axis=0,keepdims=True)
X_train_std = np.std(X_train,axis=0,keepdims=True)
X_train_norm = (X_train-X_train_mean)/X_train_std
U,s,VT = la.svd(X_train_norm,full_matrices = False)
my_rank = la.matrix_rank(X_train_norm)
print(f'The rank of the data is {my_rank}')

# let us truncate the metrics based on rank of the input matrix
U_truc = U[:,:my_rank]
lambda_e = np.diag(s)[0:my_rank,0:my_rank]
VT_trunc = VT[0:my_rank,:]
print(f'The s-matrix has {s[0:5]} as first 5 elements')
# Out:
# The rank of the data is 30
# The s-matrix has [77.97715536 50.09637951 36.46620064 29.71006652 27.60593421] as first 5 elements

# %% [markdown]
# ### Let us pick n=3 attributes from the reduced dimension

# %%
# 
transformed_data = np.matmul(X_train_norm,VT_trunc.T)
# let us just take 2 principal components for printing in plot
transformed_data_2 = transformed_data[:,:3]
# let us create a pandas dataframe for easier plotting
transformed_dataframe_X_Train = pd.DataFrame(data=transformed_data_2,columns=['pc1','pc2','pc3'])
dataframe_Y_train = pd.DataFrame(data=Y_train,columns=['diagnosis'])
#let us concatenate with the actual class labels here
to_print_df = pd.concat([transformed_dataframe_X_Train,dataframe_Y_train],axis=1)
to_print_df.head()
# Out:
#         pc1       pc2       pc3 diagnosis
# 0 -2.118090 -1.768221  1.128771         B
# 1  3.737353 -0.916104 -3.657630         M
# 2 -2.229730  1.845526  0.287852         B
# 3  1.692036 -2.313053  3.171619         M
# 4  1.706806 -1.539393  1.934860         M

# %% [markdown]
# ### Variance Computation for n=3

# %%
# Let us find the variance % represented by 3 principal components
squared = np.square(s)
# following lines of code will probe the different attributes to find the suitable number
## of attributes that will capture most variance
for i in range(1,11):
    print(f'{i} attributes capture {100*np.sum(squared[0:i])/np.sum(squared):.4f}% variance',',')
# Out:
# 1 attributes capture 44.5453% variance ,
# 2 attributes capture 62.9310% variance ,
# 3 attributes capture 72.6730% variance ,
# 4 attributes capture 79.1396% variance ,
# 5 attributes capture 84.7227% variance ,
# 6 attributes capture 88.9989% variance ,
# 7 attributes capture 91.2087% variance ,
# 8 attributes capture 92.7712% variance ,
# 9 attributes capture 94.1040% variance ,
# 10 attributes capture 95.2335% variance ,

# %% [markdown]
# ### Let us plot the transformed data here to see how they classifiy

# %%
def print_3_3Ds(my_data_frame):
    fig = plt.figure(figsize=plt.figaspect(0.5))
    ax = fig.add_subplot(1, 3, 1, projection='3d')
    ax.set_xlabel('PC 1', fontsize = 15)
    ax.set_ylabel('PC 2', fontsize = 15)
    ax.set_zlabel('PC 3', fontsize = 15)
    ax.set_title('3 PCA', fontsize = 20)
    targets = ['M', 'B']
    colors = ['r', 'g']
    for target, color in zip(targets,colors):
        indicesToKeep = my_data_frame['diagnosis'] == target
        ax.scatter3D(my_data_frame.loc[indicesToKeep, 'pc1']
                   , my_data_frame.loc[indicesToKeep, 'pc2']
                    , my_data_frame.loc[indicesToKeep, 'pc3']
                   , c = color
                   , s = 5)
    ax.legend(targets)
    ax.grid()

    ax = fig.add_subplot(1,3, 2, projection='3d')
    ax.set_xlabel('PC 3', fontsize = 15)
    ax.set_ylabel('PC 1', fontsize = 15)
    ax.set_zlabel('PC 2', fontsize = 15)
    ax.set_title('3 PCA', fontsize = 20)
    targets = ['M', 'B']
    colors = ['r', 'g']
    for target, color in zip(targets,colors):
        indicesToKeep = my_data_frame['diagnosis'] == target
        ax.scatter3D(my_data_frame.loc[indicesToKeep, 'pc3']
                    , my_data_frame.loc[indicesToKeep, 'pc1']
                   , my_data_frame.loc[indicesToKeep, 'pc2']
                   , c = color
                   , s = 5)
    ax.legend(targets)
    ax.grid()

    ax = fig.add_subplot(1,3, 3, projection='3d')
    ax.set_xlabel('PC 2', fontsize = 15)
    ax.set_ylabel('PC 3', fontsize = 15)
    ax.set_zlabel('PC 1', fontsize = 15)
    ax.set_title('3 PCA', fontsize = 20)
    targets = ['M', 'B']
    colors = ['r', 'g']
    for target, color in zip(targets,colors):
        indicesToKeep = my_data_frame['diagnosis'] == target
        ax.scatter3D(my_data_frame.loc[indicesToKeep, 'pc2']
                    , my_data_frame.loc[indicesToKeep, 'pc3']
                   , my_data_frame.loc[indicesToKeep, 'pc1']
                   , c = color
                   , s = 5)
    ax.legend(targets)
    ax.grid()
    plt.tight_layout()
print_3_3Ds(to_print_df)

# %% [markdown]
# ## Let us fit and transform our data

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
# print(X_train[0])
X_test = sc.transform(X_test)
# print(X_test[0])

# %% [markdown]
# ## Analysis: Simple Distance Metric

# %% [markdown]
# ### Here we will use KNN classifier to train and classify the data points. We will model a KNN with Minkowski Distance to use n=2 so that it will use Euclidean Distance metric. We will make it model 5% of data points to be nearest neighbour

# %%
# create a model for KNN
# n_neighbour = 5% size of train data sets,
# metric = minkowski to use a genralized distance metric
# p=2 for minkowski will use Euclidean distance
KNN_Classifier = KNeighborsClassifier(n_neighbors = int(0.05*X_train.shape[0]), p = 2, metric='minkowski')

# let us train the model
KNN_Classifier.fit(X_train,Y_train)

# let us test the classification of the test datasets that we have
Y_pred_KNN = KNN_Classifier.predict(X_test)
print(f'{len(Y_pred_KNN[Y_pred_KNN==Y_test])} out of {len(Y_test)} values are correctly predicted.\n\tAccuracy={len(Y_pred_KNN[Y_pred_KNN==Y_test])/len(Y_test)}')
confusion_KNN = confusion_matrix(Y_test,Y_pred_KNN)
print(f'\nThe confusion matrix is:\n{confusion_KNN}')
print(classification_report(Y_test, Y_pred_KNN, target_names=['Class 0','Class 1']))
# Out:
# 112 out of 114 values are correctly predicted.
# 	Accuracy=0.9824561403508771
#
# The confusion matrix is:
# [[80  0]
#  [ 2 32]]
#               precision    recall  f1-score   support
#
#      Class 0       0.98      1.00      0.99        80
#      Class 1       1.00      0.94      0.97        34
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# ## Analysis: Logistic Regression
# ### Let us use Logistic Regression as a classifier here.

# %%
Logistic_Classifier = LogisticRegression(random_state=0, solver='lbfgs')
Logistic_Classifier.fit(X_train,Y_train)
Y_pred_LC = Logistic_Classifier.predict(X_test)
print(f'{len(Y_pred_LC[Y_pred_LC==Y_test])} out of {len(Y_test)} values are correctly predicted.\n\tAccuracy={len(Y_pred_LC[Y_pred_LC==Y_test])/len(Y_test)}')
confusion_LC = confusion_matrix(Y_test,Y_pred_LC)
print(f'\nThe confusion matrix is:\n{confusion_LC}')
print(classification_report(Y_test, Y_pred_LC, target_names=['Class 0','Class 1']))
# Out:
# 110 out of 114 values are correctly predicted.
# 	Accuracy=0.9649122807017544
#
# The confusion matrix is:
# [[76  4]
#  [ 0 34]]
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.95      0.97        80
#      Class 1       0.89      1.00      0.94        34
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.97      0.96       114
# weighted avg       0.97      0.96      0.97       114

# %% [markdown]
# ## Analysis: Decision Tree Classifier
# ### Let us construct Decision Tree Classifier using both criteria

# %% [markdown]
# ### 1. Entropy

# %%
Entropy_Classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
Entropy_Classifier.fit(X_train,Y_train)
Y_pred_entropy = Entropy_Classifier.predict(X_test)
print(f'{len(Y_pred_entropy[Y_pred_entropy==Y_test])} out of {len(Y_test)} values are correctly predicted.\n\tAccuracy={len(Y_pred_entropy[Y_pred_entropy==Y_test])/len(Y_test)}')
confusion_entropy = confusion_matrix(Y_test,Y_pred_entropy)
print(f'\nThe confusion matrix is:\n{confusion_entropy}')

##set up the parameters
rcParams['figure.figsize'] = 80,50

tree.plot_tree(Entropy_Classifier)
print(classification_report(Y_test, Y_pred_entropy, target_names=['Class 0','Class 1']))
# Out:
# 102 out of 114 values are correctly predicted.
# 	Accuracy=0.8947368421052632
#
# The confusion matrix is:
# [[70 10]
#  [ 2 32]]
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.88      0.92        80
#      Class 1       0.76      0.94      0.84        34
#
#     accuracy                           0.89       114
#    macro avg       0.87      0.91      0.88       114
# weighted avg       0.91      0.89      0.90       114

# %% [markdown]
# ### 2. Gini

# %%
Gini_Classifier = DecisionTreeClassifier(criterion = 'gini', random_state = 0)
Gini_Classifier.fit(X_train,Y_train)
Y_pred_gini = Gini_Classifier.predict(X_test)
print(f'{len(Y_pred_gini[Y_pred_gini==Y_test])} out of {len(Y_test)} values are correctly predicted.\n\tAccuracy={len(Y_pred_gini[Y_pred_gini==Y_test])/len(Y_test)}')
confusion_gini = confusion_matrix(Y_test,Y_pred_gini)
print(f'\nThe confusion matrix is:\n{confusion_gini}')

##set up the parameters
rcParams['figure.figsize'] = 80,50

tree.plot_tree(Gini_Classifier)
print(classification_report(Y_test, Y_pred_gini, target_names=['Class 0','Class 1']))
# Out:
# 103 out of 114 values are correctly predicted.
# 	Accuracy=0.9035087719298246
#
# The confusion matrix is:
# [[69 11]
#  [ 0 34]]
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.86      0.93        80
#      Class 1       0.76      1.00      0.86        34
#
#     accuracy                           0.90       114
#    macro avg       0.88      0.93      0.89       114
# weighted avg       0.93      0.90      0.91       114

# %% [markdown]
# ## Analysis: Naiive Bayes Method
# There are 5 different implementations of Naive Bayes in Scikit Learn. Here we will use Gaussian Naiive Bayes.

# %% [markdown]
# ### Gaussian NB

# %%
# using Gaussian Naive Bayes
classifier_gaussian = GaussianNB()
classifier_gaussian.fit(X_train, Y_train)
Y_pred_gaussian = classifier_gaussian.predict(X_test)
print(f'\nThe confusion matrix is:\n{confusion_matrix(Y_test,Y_pred_gaussian)}')
print(classification_report(Y_test, Y_pred_gaussian, target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
# [[73  7]
#  [ 2 32]]
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.91      0.94        80
#      Class 1       0.82      0.94      0.88        34
#
#     accuracy                           0.92       114
#    macro avg       0.90      0.93      0.91       114
# weighted avg       0.93      0.92      0.92       114

# %% [markdown]
# ## Analysis: SVM
# There are three classes of SVM that can be used. We will use all of them for our classification.
# ### 1. SVC
# SVC stands for Support Vector Classification. The kernel is uses can either be Linear or Radial Basis Function

# %%
classifier_SVC_linear = svm.SVC(kernel = 'linear', random_state = 0)
classifier_SVC_linear.fit(X_train,Y_train)
Y_pred_SVM_linear = classifier_SVC_linear.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_SVM_linear)}')
print(classification_report(Y_test,Y_pred_SVM_linear,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[73  7]
#  [ 0 34]]
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.91      0.95        80
#      Class 1       0.83      1.00      0.91        34
#
#     accuracy                           0.94       114
#    macro avg       0.91      0.96      0.93       114
# weighted avg       0.95      0.94      0.94       114

# %%
classifier_SVC_radial = svm.SVC(kernel = 'rbf', random_state = 0)
classifier_SVC_radial.fit(X_train,Y_train)
Y_pred_SVM_rbf = classifier_SVC_radial.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_SVM_rbf)}')
print(classification_report(Y_test,Y_pred_SVM_rbf,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[77  3]
#  [ 0 34]]
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.96      0.98        80
#      Class 1       0.92      1.00      0.96        34
#
#     accuracy                           0.97       114
#    macro avg       0.96      0.98      0.97       114
# weighted avg       0.98      0.97      0.97       114

# %% [markdown]
# ### 2. Linear SVC

# %%
classifier_SVC_linear = svm.LinearSVC()
classifier_SVC_linear.fit(X_train,Y_train)
Y_pred_SVM_linear = classifier_SVC_linear.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_SVM_linear)}')
print(classification_report(Y_test,Y_pred_SVM_linear,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[72  8]
#  [ 0 34]]
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.90      0.95        80
#      Class 1       0.81      1.00      0.89        34
#
#     accuracy                           0.93       114
#    macro avg       0.90      0.95      0.92       114
# weighted avg       0.94      0.93      0.93       114

# %% [markdown]
# ### 3. NuSVC

# %%
classifier_SVC_nu = svm.NuSVC(gamma='scale')
classifier_SVC_nu.fit(X_train,Y_train)
Y_pred_SVM_nu = classifier_SVC_nu.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_SVM_nu)}')
print(classification_report(Y_test,Y_pred_SVM_nu,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[75  5]
#  [ 2 32]]
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.94      0.96        80
#      Class 1       0.86      0.94      0.90        34
#
#     accuracy                           0.94       114
#    macro avg       0.92      0.94      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# ## Analysis: MultiLayer Perceptron

# %% [markdown]
# Here we will use a MLP Classifier offered by SK Learn. The number of layers is defaulted, ie 100. Since our dataset is smaller, we use lbfgs as our solver.

# %%
classifier_MLP = MLPClassifier(solver='lbfgs', alpha=1e-5, random_state=1)
classifier_MLP.fit(X_train,Y_train)
Y_pred_MLP = classifier_MLP.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_MLP)}')
print(classification_report(Y_test,Y_pred_MLP,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[74  6]
#  [ 0 34]]
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.93      0.96        80
#      Class 1       0.85      1.00      0.92        34
#
#     accuracy                           0.95       114
#    macro avg       0.93      0.96      0.94       114
# weighted avg       0.96      0.95      0.95       114

# %% [markdown]
# ## Analysis: Random Forest Classifier
# Let us analyse using random forest classifier as well. From our earlier observation for Decision Tree, better results were obtained for gini, so we will use gini as the criteria here.

# %%
classifier = RandomForestClassifier(n_estimators = 30, criterion = 'gini', random_state = 0)
classifier.fit(X_train, Y_train)
Y_pred_rf = classifier.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_rf)}')
print(classification_report(Y_test,Y_pred_rf,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[72  8]
#  [ 1 33]]
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.90      0.94        80
#      Class 1       0.80      0.97      0.88        34
#
#     accuracy                           0.92       114
#    macro avg       0.90      0.94      0.91       114
# weighted avg       0.93      0.92      0.92       114

# %% [markdown]
# Let us try same with entropy as the criteria

# %%
classifier = RandomForestClassifier(n_estimators = 30, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, Y_train)
Y_pred_rf = classifier.predict(X_test)
print(f'The confusion matrix is:\n {confusion_matrix(Y_test,Y_pred_rf)}')
print(classification_report(Y_test,Y_pred_rf,target_names=['Class 0','Class 1']))
# Out:
# The confusion matrix is:
#  [[75  5]
#  [ 1 33]]
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.94      0.96        80
#      Class 1       0.87      0.97      0.92        34
#
#     accuracy                           0.95       114
#    macro avg       0.93      0.95      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %% [markdown]
# # Conclusion
# Based on our observation from above, following lists the accuracy result from all the Classifiers

# %% [markdown]
# | Classification Method | Accuracy (%)   |
# |------|------|
# | Random Forest (Gini) | 92 |
# | Random Forest (Entropy) | 95 |
# | Multi Layer Perception | 95 |
# | SVM NuSVC | 94 |
# | SVM LinearSVC | 93 |
# | SVM SVC Linear | 94 |
# | SVM SVC RBF | 97 |
# | Gaussian Naive Bayes | 92 |
# | Decision Tree (Gini) | 90 |
# | Decision Tree (Entropy) | 89 |
# | Logistic Regression | 96 |
# | KNN | 98.2 |

# %% [markdown]
# ### Since KNN has the highest accuracy value of all the models used, classification can be done best using KNN. This claim is supported by the better values of precision and recall values seen in KNN as well.
